# %% [markdown]
# <a href="https://colab.research.google.com/github/himanshivarma/AudioSegmentSplitting/blob/main/Wav2vecmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install s3prl[all]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 19.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 38.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.6/229.6 kB 14.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 27.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 16.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 47.1 MB/s eta 0:00:00
# ...

# %%
import torch
import torchaudio
import s3prl.hub as hub
from google.colab import files
model_3 = getattr(hub, 'wav2vec2')()
device = 'cuda'
model_3 = model_3.to(device)

uploaded = files.upload()
audio_path = "audio.wav"
waveform, _ = torchaudio.load(audio_path)
waveform = waveform.to(device)
# Repeating the waveform to match the batch size of the model!!
batch_size = 16
wavs = waveform.expand(batch_size, -1)
with torch.no_grad():
    reps = model_3(wavs)["hidden_states"]
# Out:
# Downloading: https://huggingface.co/s3prl/converted_ckpts/resolve/main/wav2vec_small.pt
# Destination: /root/.cache/s3prl/download/aa064e275fe0123a0e1b515f2341bbe4408368510d91d0a6816f2822a6e5acdd.wav2vec_small.pt
# 100%|██████████| 181M/181M [00:00<00:00, 210MB/s]
#      <input type="file" id="files-b14addb8-4121-4482-9c24-24aad42d3825" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b14addb8-4121-4482-9c24-24aad42d3825">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# ...

# %%
print(dir(hub))
# Out:
# ['DEFAULT_CONFIG_PATH', 'FileLock', 'NEW_ENOUGH_SECS', 'Path', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'apc', 'apc_360hr', 'apc_960hr', 'apc_local', 'apc_url', 'ast', 'audio_albert', 'audio_albert_960hr', 'audio_albert_local', 'audio_albert_logMelBase_T_share_AdamW_b32_1m_960hr_drop1', 'audio_albert_url', 'baseline', 'baseline_local', 'byol_a_1024', 'byol_a_2048', 'byol_a_512', 'byol_s_cvt', 'byol_s_default', 'byol_s_resnetish34', 'cpc_local', 'cpc_url', 'customized_upstream', 'data2vec', 'data2vec_base_960', 'data2vec_custom', 'data2vec_large_ll60k', 'data2vec_local', 'data2vec_url', 'decoar', 'decoar2', 'decoar2_custom', 'decoar2_local', 'decoar2_url', 'decoar_custom', 'decoar_layers', 'decoar_layers_custom', 'decoar_layers_local', 'decoar_layers_url', 'decoar_local', 'decoar_url', 'discretebert', 'distilhubert', 'distilhubert_base', 'distiller_local', 'distiller_url', 'fbank', 'fbank_no_cmvn', 'glob', 'hf_hubert_cus
# ...

# %%
# !pip install torchaudio
